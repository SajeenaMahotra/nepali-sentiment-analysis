# %%
import joblib
from sklearn.metrics import classification_report

X_test, y_test = joblib.load('../data/processed/test_features.pkl')

nb_model = joblib.load('../models/naive_bayes_model.pkl')
svm_model = joblib.load('../models/svm_model.pkl')
lr_model = joblib.load('../models/logistic_regression_model.pkl')

# %%
pred = nb_model.predict(X_test)
print("Naive Bayes (TEST SET)")
print(classification_report(y_test, pred))
# Out:
# Naive Bayes (TEST SET)
#               precision    recall  f1-score   support
#
#     negative       0.77      0.48      0.59       176
#      neutral       0.60      0.24      0.34       178
#     positive       0.60      0.94      0.73       298
#
#     accuracy                           0.63       652
#    macro avg       0.65      0.56      0.56       652
# weighted avg       0.64      0.63      0.59       652

# %%
pred = svm_model.predict(X_test)
print("SVM (TEST SET)")
print(classification_report(y_test, pred))
# Out:
# SVM (TEST SET)
#               precision    recall  f1-score   support
#
#     negative       0.66      0.64      0.65       176
#      neutral       0.53      0.48      0.50       178
#     positive       0.74      0.80      0.77       298
#
#     accuracy                           0.67       652
#    macro avg       0.65      0.64      0.64       652
# weighted avg       0.66      0.67      0.67       652

# %%
pred = lr_model.predict(X_test)
print("Logistic Regression (TEST SET)")
print(classification_report(y_test, pred))
# Out:
# Logistic Regression (TEST SET)
#               precision    recall  f1-score   support
#
#     negative       0.66      0.71      0.68       176
#      neutral       0.51      0.48      0.49       178
#     positive       0.78      0.77      0.77       298
#
#     accuracy                           0.67       652
#    macro avg       0.65      0.65      0.65       652
# weighted avg       0.67      0.67      0.67       652
